# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read an image
img = cv2.imread('./Data/male.jfif')

# %%
# convert into gray scale
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
# apply cascade classifier
haar = cv2.CascadeClassifier('./Data/haarcascade_frontalface_default.xml')
faces= haar.detectMultiScale(gray,1.3,5)

# %%
print(faces) #( x=48,y=54,w=120,h=)
# Out:
# [[ 48  54 120 120]]

# %%
cv2.rectangle(img,(48,54),(48+120,54+120),(0,255,0),3)
plt.imshow(img)

# %%
# cv2.imshow('object_detect',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# CROP image
face_crop = img[54:54+120,48:48+120]
plt.imshow(face_crop)

# %%
cv2.imwrite('./Data/male_01.png',face_crop)
# Out:
# True
